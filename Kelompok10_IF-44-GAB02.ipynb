# %% [markdown]
# <center>
# <b><font size="5">TUGAS BESAR STATISTIKA</font></b>
# <br>
# Muhamad Rafli Susanto - 1301204052<br>
# Adhitya Melani Eka Janarwati - 1301204046<br>
# Galih Atha Fayi Khansa - 1301204028<br>
# Denny Sofyan - 1301204036

# %% [markdown]
# **Pendahuluan**<br>
# Pada analisis ini data yang digunakan berasal dari: <br>
# https://www.kaggle.com/sakshigoyal7/credit-card-customers
# <br>
# <br>
# Analisis ini dilakukan dengan tujuan untuk mendapat gambaran tentang karakteristik pemegang kartu kredit yang berpindah ke bank lain (Churning) serta untuk memenuhi tugas besar statistika.

# %% [markdown]
# **Deskripsi Tugas**

# %% [markdown]
# I. **TUJUAN**: <br>Mahasiswa mampu menerapkan metode-metode deskripsi data, pengolahan dan analisis data   (kategorik maupun kuantitatif)  untuk menyelesaikan masalah  keteknikan dengan prinsip-prinsip computing
#
# II. **Uraian** **Tugas**: <br>Manager suatu bank ingin mendapat gambaran tentang karakteristik pemegang kartu kredit yang mereka terbitkan, berdasarkan data berisi fitur-fitur pemegang kartu kredit (kolom A-U) dan peluang pemegang kartu kredit berpindah ke bank lain (kolom V dan W).
# - Lakukan eksplorasi menggunakan metode yang sudah dipelajari untuk mendapatkan informasi yang akan anda presentasikan kepada manager bank.

# %% [markdown]
# **1. Meng-import data pelanggan kartu kredit (BankChurners.csv)**<br>
# Memanggil data dari GitHub untuk dimasukkan dalam variabel MyRData

# %%
MyRData <- read.csv("https://raw.githubusercontent.com/raflisusanto/tubes_statistika/main/BankChurners.csv", header = TRUE)

# %% [markdown]
# **2. Menginstall library yang akan dipakai.**<br>
# Library berikut dipakai untuk membantu dalam analisis data

# %%
install.packages("ggplot2")
install.packages("gridExtra")
install.packages("dplyr")
install.packages("GGally")
library(ggplot2)
library(gridExtra)
library(dplyr)
library(GGally)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘plyr’, ‘reshape’
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:gridExtra’:
#
#     combine
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %% [markdown]
# # **3. Summary dan Garis Besar Data**

# %% [markdown]
# Di bawah ini ditampilkan summary dari data pelanggan kartu kredit

# %%
summary(MyRData)
# Out:
#    CLIENTNUM         Attrition_Flag      Customer_Age      Gender
#  Min.   :708082083   Length:10127       Min.   :26.00   Length:10127
#  1st Qu.:713036770   Class :character   1st Qu.:41.00   Class :character
#  Median :717926358   Mode  :character   Median :46.00   Mode  :character
#  Mean   :739177606                      Mean   :46.33
#  3rd Qu.:773143533                      3rd Qu.:52.00
#  Max.   :828343083                      Max.   :73.00
#  Dependent_count Education_Level    Marital_Status     Income_Category
#  Min.   :0.000   Length:10127       Length:10127       Length:10127
#  1st Qu.:1.000   Class :character   Class :character   Class :character
#  Median :2.000   Mode  :character   Mode  :character   Mode  :character
#  Mean   :2.346
#  3rd Qu.:3.000
#  Max.   :5.000
#  Card_Category      Months_on_book  Total_Relationship_Count
#  Length:10127       Min.   :13.00   Min.   :1.000
#  Class :character   1st Qu.:31.00   1st Qu.:3.000
# ...

# %% [markdown]
# Dibawah ini ditampilkan sampel data dari data pelanggan kartu kredit (3 data teratas dan 3 data terakhir)

# %%
head(MyRData,3)
tail(MyRData,3)
# Out:
#   CLIENTNUM Attrition_Flag    Customer_Age Gender Dependent_count
# 1 768805383 Existing Customer 45           M      3
# 2 818770008 Existing Customer 49           F      5
# 3 713982108 Existing Customer 51           M      3
#   Education_Level Marital_Status Income_Category Card_Category Months_on_book ⋯
# 1 High School     Married        $60K - $80K     Blue          39             ⋯
# 2 Graduate        Single         Less than $40K  Blue          44             ⋯
# 3 Graduate        Married        $80K - $120K    Blue          36             ⋯
#   Credit_Limit Total_Revolving_Bal Avg_Open_To_Buy Total_Amt_Chng_Q4_Q1
# 1 12691        777                 11914           1.335
# 2  8256        864                  7392           1.541
# 3  3418          0                  3418           2.594
#   Total_Trans_Amt Total_Trans_Ct Total_Ct_Chng_Q4_Q1 Avg_Utilization_Ratio
# 1 1144            42             1.625               0.061
# ...

# %% [markdown]
# # **4. Menampilkan Visual dari Data (Data Visualization)**

# %%
slices <- table(MyRData$Attrition_Flag)
lbls <- c("Attritted Cust", "Existing Cust")
pct <- round(slices/sum(slices)*100)
lbls <- paste(lbls, pct, sep = " ")
lbls <- paste(lbls,"%", sep = "")
pie(slices,labels = lbls, col = cm.colors(length(lbls)), main = "  Attrition Flag ")
legend("bottomleft", c("Attritted Cust", "Existing Cust"), cex = 0.8, fill = cm.colors(length(lbls)))
# Out:
# Plot with title “  Attrition Flag ”

# %% [markdown]
# Dari visualisasi data diatas dapat diperoleh informasi bahwa dari total pelanggan sejumlah 10127 pelanggan:<br>
# - Memiliki Existing Customer sebanyak 84% <br>
# - Memiliki Attrited Customer sebanyak 16%

# %% [markdown]
# **Visualisasi Data Gender**

# %%
counts1 <- setNames(as.data.frame(table(MyRData$Gender)), c("Gender", "Frequency"))
df <- data.frame(Gender=counts1$Gender,
                Frequency=counts1$Frequency)

freq <- counts1$Frequency
pct <- round(100*df$Frequency/sum(df$Frequency))
lbls <- paste(pct, "%", "\n", freq, sep = " ")
ggplot(data=df, aes(x=Gender, y=Frequency, fill=Gender)) +
  geom_bar(stat="identity") +
  geom_text(aes(label=lbls), vjust=1.6, color="white", size=3.5) + 
  labs(x="Gender", y = "Frequency", fill="Education Level") +
  theme_gray()
# Out:
# plot without title

# %% [markdown]
# Dari visualisasi data diatas dapat diperoleh informasi bahwa dari total pelanggan sejumlah 10127 pelanggan:<br>
# - 53% atau 5358 pelanggan merupakan Female (Perempuan)
# - 47% atau 4769 pelanggan merupakan Male (Laki-laki)

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
slices <- table(attrited_cust$Attrition_Flag, attrited_cust$Gender)
lbls <- c("Female", "Male")
pct <- round(slices/sum(slices)*100)
lbls <- paste(lbls, pct, sep = " ")
lbls <- paste(lbls,"%", sep = "")
pie(slices,labels = lbls, col = cm.colors(length(lbls)), main = "Attrited Customer by Gender ")
legend("bottomleft", c("Female", "Male"), cex = 0.8, fill = cm.colors(length(lbls)))
# Out:
# Plot with title “Attrited Customer by Gender ”

# %% [markdown]
# Dari visualisasi data diatas, dapat didapatkan informasi bahwa:<br>
# - Pelanggan wanita lebih banyak melakukan churn dibandingkan pelanggan pria.
# Akan tetapi, tidak bisa disimpulkan bahwa jenis kelamin bisa mempengaruhi tingkat churning pelanggan.

# %% [markdown]
# **Visualisasi Data Education Level**

# %%
counts2 <- setNames(as.data.frame(table(MyRData$Education_Level)), c("Education", "Frequency"))
df <- data.frame(Education=counts2$Education,
                Frequency=counts2$Frequency)

freq <- counts2$Frequency
pct <- round(100*df$Frequency/sum(df$Frequency))
lbls <- paste(pct, "%", "\n", freq, sep = " ")
ggplot(data=df, aes(x=Education, y=Frequency, fill=Education)) +
  geom_bar(stat="identity") +
  geom_text(aes(label=lbls), vjust=1.6, color="white", size=3.5) + 
  labs(x="Education Level", y = "Frequency", fill="Education Level") +
  theme_gray()
# Out:
# plot without title

# %% [markdown]
# Dari visualisasi data diatas dapat diperoleh informasi bahwa dari total sejumlah 10127 pelanggan:<br>
# - Jika diasumsikan bahwa pelanggan dengan status pendidikan tidak diketahui (unknown) tidak memiliki pendidikan apapun, maka bisa dikatakan bahwa sekitar 70% dari pelanggan memiliki pendidikan formal.
# - Paling banyak pelanggan merupakan tingkat Graduate sebanyak 31% atau berjumlah 3128 pelanggan.

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
slices <- table(attrited_cust$Attrition_Flag, attrited_cust$Education_Level)
lbls <- c("College", "Doctorate", "Graduate", "HighSchool", "Post-Graduate", "Uneducated", "Unknown")
pct <- round(slices/sum(slices)*100)
lbls <- paste(lbls, pct, sep = " ")
lbls <- paste(lbls,"%", sep = "")
pie(slices,labels = lbls, col = cm.colors(length(lbls)), main = "Attrited Customer by Education Level ")
legend("topleft", c("College", "Doctorate", "Graduate", "HighSchool", "Post-Graduate", "Uneducated", "Unknown"), cex = 0.53, fill = rainbow(length(lbls)))
# Out:
# Plot with title “Attrited Customer by Education Level ”

# %% [markdown]
# Dari visualisasi data diatas didapatkan informasi bahwa:<br>
# - Pelanggan dengan tingkat pendidikan lulusan Graduate (30%) lebih banyak yang melakukan churning.

# %% [markdown]
# **Visualisasi Data Marital Status**

# %%
counts3 <- setNames(as.data.frame(table(MyRData$Marital_Status)), c("Marital", "Frequency"))
df <- data.frame(Marital=counts3$Marital,
                Frequency=counts3$Frequency)

freq <- counts3$Frequency
pct <- round(100*df$Frequency/sum(df$Frequency))
lbls <- paste(pct, "%", "\n", freq, sep = " ")
ggplot(data=df, aes(x=Marital, y=Frequency, fill=Marital)) +
  geom_bar(stat="identity") +
  geom_text(aes(label=lbls), vjust=1.6, color="white", size=3.5) + 
  labs(x="Marital Status", y = "Frequency", fill="Marital Status") +
  theme_gray()
# Out:
# plot without title

# %% [markdown]
# Dari visualisasi data diatas dapat diperoleh informasi bahwa dari total sejumlah 10127 pelanggan:<br>
# - Paling banyak sudah menikah yaitu sebesar 46% atau berjumlah 4687 pelanggan.

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
slices <- table(attrited_cust$Attrition_Flag, attrited_cust$Marital_Status)
lbls <- c("Divorced", "Married", "Single", "Unknown")
pct <- round(slices/sum(slices)*100)
lbls <- paste(lbls, pct, sep = " ")
lbls <- paste(lbls,"%", sep = "")
pie(slices,labels = lbls, col = cm.colors(length(lbls)), main = "Attrited Customer by Marital Status ")
legend("bottomleft", c("Divorced", "Married", "Single", "Unknown"), cex = 0.6, fill = cm.colors(length(lbls)))
# Out:
# Plot with title “Attrited Customer by Marital Status ”

# %% [markdown]
# Dari visualisasi data diatas didapatkan informasi bahwa: <br>
# - Hampir sebagian dari nasabah bank sudah menikah, dan hampir sebagian lainnya adalah nasabah yang single, serta hanya sekitar 7% pelanggan yang bercerai,
# - Pelanggan yang sudah menikah (44%) lebih banyak melakukan churn.

# %% [markdown]
# **Visualisasi Data Income Category**

# %%
counts4 <- setNames(as.data.frame(table(MyRData$Income_Category)), c("Income", "Frequency"))
df <- data.frame(Income=counts4$Income, Frequency=counts4$Frequency)

freq <- counts4$Frequency
pct <- round(100*df$Frequency/sum(df$Frequency))
lbls <- paste(pct, "%", "\n", freq, sep = " ")
ggplot(data=df, aes(x=Income, y=Frequency, fill=Income)) + geom_bar(stat="identity") + geom_text(aes(label=lbls), vjust=1.6, color="white", size=3.5) + labs(x="Income Category", y = "Frequency", fill="Income Category") + theme_gray()
# Out:
# plot without title

# %% [markdown]
# Dari visualisasi data diatas dapat diperoleh informasi bahwa dari total sejumlah 10127 pelanggan:<br>
# - Paling banyak mempunyai penghasilan kurang dari $40K yaitu sebanyak 35% atau berjumlah 3561 pelanggan.

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
slices <- table(attrited_cust$Attrition_Flag, attrited_cust$Income_Category)
lbls <- c("$120K+", "$40K - $60K", "$60K - $80K", "$80K - $120K", "<$40K", "Unknown")
pct <- round(slices/sum(slices)*100)
lbls <- paste(lbls, pct, sep = " ")
lbls <- paste(lbls,"%", sep = "")
pie(slices,labels = lbls, col = cm.colors(length(lbls)), main = "Attrited Customer by Income Category")
legend("bottomright", c("$120K+", "$40K - $60K", "$60K - $80K", "$80K - $120K", "<$40K", "Unknown"), cex = 0.8, fill = cm.colors(length(lbls)))
# Out:
# Plot with title “Attrited Customer by Income Category”

# %% [markdown]
# Dari visualisasi data diatas didapatkan informasi bahwa:
# - Kebanyakan pelanggan yang melakukan churning merupakan pelanggan yang memiliki penghasilan kurang dari $40K (40 Ribu Dollar)

# %% [markdown]
# **Visualisasi Data Card Category**

# %%
counts5 <- setNames(as.data.frame(table(MyRData$Card_Category)), c("Card", "Frequency"))
df <- data.frame(Card=counts5$Card,
                Frequency=counts5$Frequency)

freq <- counts5$Frequency
pct <- round(100*df$Frequency/sum(df$Frequency))
lbls <- paste(pct, "%", "\n", freq, sep = " ")
ggplot(data=df, aes(x=Card, y=Frequency, fill=Card)) +
  geom_bar(stat="identity") +
  geom_text(aes(label=lbls), vjust=1.6, color="white", size=3.5) + 
  labs(x="Card Category", y = "Frequency", fill="Card Category") +
  theme_gray()
# Out:
# plot without title

# %% [markdown]
# Dari visualisasi data diatas dapat diperoleh informasi bahwa dari total sejumlah 10127 pelanggan:<br>
# - Hampir keseluruhan pelanggan mempunyai kartu biru yaitu sebesar 93% atau berjumlah 9436 pelanggan.

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
slices <- table(attrited_cust$Attrition_Flag, attrited_cust$Card_Category)
lbls <- c("Blue", "Gold", "Platinum", "Silver")
pct <- round(slices/sum(slices)*100)
lbls <- paste(lbls, pct, sep = " ")
lbls <- paste(lbls,"%", sep = "")
pie(slices,labels = lbls, col = cm.colors(length(lbls)), main = "Attrited Customer by Card Category")
legend("bottomright", c("Blue", "Silver", "Gold", "Platinum"), cex = 0.8, fill = cm.colors(length(lbls)))
# Out:
# Plot with title “Attrited Customer by Card Category”

# %% [markdown]
# Dari visualisasi data diatas didapatkan informasi bahwa:<br>
# - Hampir keseluruhan pelanggan yang melakukan churn adalah pelanggan yang menggunakan kartu kredit biru, yaitu sebanyak 93%

# %% [markdown]
# **Visualisasi Distribusi Umur Attrited Customer**

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
boxplot(attrited_cust$Customer_Age, col='cyan', main="Boxplot dari Attrited Customer berdasarkan Umur")
# Out:
# Plot with title “Boxplot dari Attrited Customer berdasarkan Umur”

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
hist(attrited_cust$Customer_Age, col='pink', main="Histogram dari Attrited Customer berdasarkan Umur")
# Out:
# Plot with title “Histogram dari Attrited Customer berdasarkan Umur”

# %% [markdown]
# Dari boxplot dan histogram diatas didapatkan informasi bahwa:<br>
# - Umur pelanggan yang melakukan churn kebanyakan adalah pelanggan yang berumur sekitar 40 sampai 50 Tahun

# %% [markdown]
# **Visualisasi Distribusi Dependent Count Attrited Customer**

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
boxplot(attrited_cust$Dependent_count, col='cyan', main="Boxplot dari Attrited Customer berdasarkan Dependent Count")
# Out:
# Plot with title “Boxplot dari Attrited Customer berdasarkan Dependent Count”

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
hist(attrited_cust$Dependent_count, col='pink', main="Histogram dari Attrited Customer berdasarkan Dependent Count")
# Out:
# Plot with title “Histogram dari Attrited Customer berdasarkan Dependent Count”

# %% [markdown]
# Dari boxplot dan histogram diatas didapatkan informasi bahwa:<br>
# - Distribusi Dependent Count (Jumlah Tanggungan) didistribusikan secara normal dengan sedikit kemiringan kanan.
# - Kebanyakan Pelanggan yang melakukan churn adalah pelanggan yang memilki tanggungan 2-3

# %% [markdown]
# **Visualisasi Distribusi Months on Book dari Attrited Customer**

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
boxplot(attrited_cust$Months_on_book, col='cyan', main="Boxplot dari Attrited Customer berdasarkan Months on book")
# Out:
# Plot with title “Boxplot dari Attrited Customer berdasarkan Months on book”

# %% [markdown]
# 1. Kebanyakan pelanggan yang melakukan churning adalah pelanggan yang sudah berlangganan selama 35-40 bulan.
# 2. Pelanggan tercepat selama 20 bulan dan pelanggan dengan waktu terlama yakni > 50 bulan.
# 3. Penyebaran data terlihat simetris.

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
hist(attrited_cust$Months_on_book, col='pink', main="Histogram dari Attrited Customer berdasarkan Months on book")
# Out:
# Plot with title “Histogram dari Attrited Customer berdasarkan Months on book”

# %% [markdown]
# Dari visualisasi data diatas dapat diperoleh informasi bahwa:<br>
# - Kebanyakan pelanggan yang melakukan churning adalah pelanggan yang sudah berlangganan selama 35-40 bulan atau <br>sekitar 2,9 - 3,3 tahun.

# %% [markdown]
# **Visualisasi Distribusi Total Relationship Count dari Attrited Customer**

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
boxplot(attrited_cust$Total_Relationship_Count, col='cyan', main="Boxplot dari Attrited Customer berdasarkan Total Relationship Count")
# Out:
# Plot with title “Boxplot dari Attrited Customer berdasarkan Total Relationship Count”

# %% [markdown]
# 1. Kebanyakan pelanggan yang melakukan churning memiliki jumlah produk sebanyak 2-3.
# 2. Jumlah produk terendah sebanyak 1 dan jumlah produk terbesar sebanyak 3.
# 3. Data lebih menyebar keatas.

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
hist(attrited_cust$Total_Relationship_Count, col='pink', main="Histogram dari Attrited Customer berdasarkan Total Relationship Count")
# Out:
# Plot with title “Histogram dari Attrited Customer berdasarkan Total Relationship Count”

# %% [markdown]
# Dari visualisasi data diatas dapat diperoleh informasi bahwa:<br>
# - Kebanyakan pelanggan yang melakukan churning memiliki jumlah produk sebanyak 2-3.
# - Dari grafik distribusi diatas tampaknya hampir seragam dan tidak terlalu relevan untuk sebagai prediktor status churn.

# %% [markdown]
# **Visualisasi Distribusi Months Inactive dalam 12 Bulan Terakhir dari Attrited Customer**

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
boxplot(attrited_cust$Months_Inactive_12_mon, col='cyan', main="Boxplot berdasarkan Months Inactive dalam 12 bulan terakhir")
# Out:
# Plot with title “Boxplot berdasarkan Months Inactive dalam 12 bulan terakhir”

# %% [markdown]
# 1. Kebanyakan pelanggan yang melakukan churning sudah tidak aktif selama 2-3 bulan.
# 2. Lama  pelanggan tidak aktif paling sedikit yakni 1 bulan dan lama pelanggan tidak aktif tertinggi yakni 4 bulan lebih.
# 3. Data menyebar kebawah.

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
hist(attrited_cust$Months_Inactive_12_mon, col='pink', main="Histogram berdasarkan Months Inactive dalam 12 bulan terakhir")
# Out:
# Plot with title “Histogram berdasarkan Months Inactive dalam 12 bulan terakhir”

# %% [markdown]
# Dari visualisasi data diatas dapat diperoleh informasi bahwa:<br>
# - Kebanyakan pelanggan yang melakukan churning sudah tidak aktif selama 2-3 bulan dalam 12 bulan terakhir.

# %% [markdown]
# **Visualisasi Distribusi Credit Limit dari Attrited Customer**

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
boxplot(attrited_cust$Credit_Limit, col='cyan', main="Boxplot dari Attrited Customer berdasarkan Credit Limit")
# Out:
# Plot with title “Boxplot dari Attrited Customer berdasarkan Credit Limit”

# %% [markdown]
# 1. Kebanyakan pelanggan yang melakukan churning mempunyai limit kredit sebesar \$0-\$5000.
# 2. Kredit limit yang terendah dari pelanggan sebesar < \$2500 dan kredit limit terbesar dari pelanggan sebesar \$10000.
# 3. Data lebih menyebar keatas.

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
hist(attrited_cust$Credit_Limit, col='pink', main="Histogram dari Attrited Customer berdasarkan Credit Limit")
# Out:
# Plot with title “Histogram dari Attrited Customer berdasarkan Credit Limit”

# %% [markdown]
# Dari visualisasi data diatas dapat diperoleh informasi bahwa:<br>
# - Kebanyakan pelanggan yang melakukan churning mempunyai limit kredit sebesar \$0-\$5000

# %% [markdown]
# **Visualisasi Distribusi Total Transaction Amount dari Attrited Customer**

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
boxplot(attrited_cust$Total_Trans_Amt, col='cyan', main="Boxplot dari Attrited Cust berdasarkan Total Transaction Amount")
# Out:
# Plot with title “Boxplot dari Attrited Cust berdasarkan Total Transaction Amount”

# %% [markdown]
# Dari Boxplot diatas dapat diperoleh informasi :
# 1. Pelanggan yang melakukan churning, kebanyakan mempunyai total transaksi sebesar \$2000-\$3000.
# 2. Transaksi terendah dari pelanggan yakni sebesar < \$1000
#   dan transaksi tertinggi dari pelanggan yakni sebesar \$4000.
# 3. Penyebaran data simetris

# %%
attrited_cust <- MyRData[MyRData$Attrition_Flag == "Attrited Customer", ]
hist(attrited_cust$Total_Trans_Amt, col='pink', main="Histogram dari Attrited Cust berdasarkan Total Transaction Amount")
# Out:
# Plot with title “Histogram dari Attrited Cust berdasarkan Total Transaction Amount”

# %% [markdown]
# Dari visualisasi data diatas dapat diperoleh informasi bahwa:<br>
# - Pelanggan yang melakukan churning, kebanyakan mempunyai total transaksi sebesar \$2000-\$3000.
# - Jika dilihat lebih lanjut, grafik distribusi terlihat bisa dipecah menjadi beberapa grup. (\$0-\$3000, \$3000-\$7000, \$7000-\$10000, \$10000+)

# %% [markdown]
# # **5. Mencari Korelasi Antar Data**

# %% [markdown]
# **Menyaring Data Numeric pada Data Credit Card Customer.**

# %%
MyRData.numeric <- MyRData[,sapply(MyRData, is.numeric)]

# %% [markdown]
# **Mencari Hubungan/Korelasi Antar Data.**

# %%
res <- cor(MyRData.numeric)
round(res, 2)
# Out:
#                                                                                                                                    CLIENTNUM
# CLIENTNUM                                                                                                                           1.00
# Customer_Age                                                                                                                        0.01
# Dependent_count                                                                                                                     0.01
# Months_on_book                                                                                                                      0.13
# Total_Relationship_Count                                                                                                            0.01
# Months_Inactive_12_mon                                                                                                              0.01
# ...

# %% [markdown]
# Dari analisis korelasi yang dilakukan di atas didapatkan informasi bahwa:<br>
# - Customer Age memiliki hubungan yang besar dengan Months on book dengan nilai korelasi sebesar 0.79
# - Avg_Utilization Ratio memiliki hubungan yang cukup besar dengan Total_Revolving_Bal dengan nilai korelasi sebesar 0.62
# - Total_Trans_Amt memiliki hubungan yang besar dengan Total_Trans_Ct dengan nilai korelasi sebesar 0.81
# - Total_Amt_Chng_Q4_Q1 memiliki hubungan yang cukup besar dengan Total_Ct_Chng_Q4_Q1 dengan nilai korelasi sebesar 0.38

# %% [markdown]
# # **6. Membuat Visualisasi dari Data yang Memiliki Korelasi Cukup Besar**

# %% [markdown]
# **a. Customer Age dengan Months on Book**

# %%
# Menampilkan Korelasi dan Scatter Plot antara Months_on_book dengan Customer_Age
ggplot(MyRData, aes(x = Months_on_book, y = Customer_Age, color= Months_on_book)) +
  labs(x="Months on Book", y = "Customer Age", color="Months on Book") +
  geom_point()
# Out:
# plot without title

# %%
#Menampilkan keterhubungan antara Months_on_book dengan Customer_Age
MyRData %>%
  select(Months_on_book, Customer_Age) %>%
  ggpairs()
# Out:
# plot without title

# %% [markdown]
# Plot ini menghubungkan variabel antara Months_on_book dengan Customer_age. Dilihat dari grafik diatas terdapat hubungan antara months_on_book dengan Customer_age, sehingga semakin lama pelanggan merupakan bagian dari bank, semakin besar pula umur dari pelanggan

# %% [markdown]
# **b. Average Utilization Ratio dengan Total Revolving Balance**

# %%
ggplot(MyRData, aes(x = Avg_Utilization_Ratio, y = Total_Revolving_Bal, color= Avg_Utilization_Ratio)) +
  labs(x="Average Utilization Ratio", y = "Total Revolving Balance", color="Average Utilization Ratio") +
  geom_point()
# Out:
# plot without title

# %%
#Menampilkan keterhubungan antara Avg_Utilization_Ratio dengan Total_Revolving_Bal
MyRData %>%
  select(Avg_Utilization_Ratio, Total_Revolving_Bal) %>%
  ggpairs()
# Out:
# Warning message in warn_if_args_exist(list(...)):
# “Extra arguments: 'color' are being ignored.  If these are meant to be aesthetics, submit them using the 'mapping' variable within ggpairs with ggplot2::aes or ggplot2::aes_string.”
# plot without title

# %% [markdown]
# Plot ini menghubungkan variabel antara Avg_Utilization_Ratio dengan Total_Revolving_bal. Dilihat dari grafik diatas terdapat hubungan antara Avg_Utilization_Ratio dengan Total_Revolving_bal, sehingga semakin banyak saldo keluar/bergulir, semakin banyak pula rata-rata penggunaan kartu kredit (utilization ratio)

# %% [markdown]
# **c. Total Transaction Amount dengan Total Transaction Count**

# %%
ggplot(MyRData, aes(x = Total_Trans_Amt, y = Total_Trans_Ct, color= Total_Trans_Amt)) +
  labs(x="Total Transaction Amount", y = "Total Transaction Count", color="Total Transaction Amount") +
  geom_point()
# Out:
# plot without title

# %%
#Menampilkan keterhubungan antara Total_Trans_Amt dengan Total_Trans_Ct
MyRData %>%
  select(Total_Trans_Amt, Total_Trans_Ct) %>%
  ggpairs()
# Out:
# plot without title

# %% [markdown]
# Plot ini menghubungkan variabel antara Total_Trans_Amt dengan Total_Trans_Ct. Dilihat dari grafik diatas terdapat hubungan antara Total_Trans_Amt dengan Total_Trans_Ct, sehingga semakin banyak Transaction amount, semakin banyak pula transaction count nya

# %% [markdown]
# **d. Total Transaction Amount Change Q4 Q1 dengan Total Transaction Count Change Q4 Q1**

# %%
ggplot(MyRData, aes(x = Total_Amt_Chng_Q4_Q1, y = Total_Ct_Chng_Q4_Q1, color=Total_Amt_Chng_Q4_Q1)) +
  labs(x="Total Amount Change Q4 Q1", y = "Total Count Change Q4 Q1", color="Total Amount Change Q4 Q1") +
  geom_point()
# Out:
# plot without title

# %%
#Menampilkan keterhubungan antara Total_Amt_Chng_Q4_Q1 dengan Total_Ct_Chng_Q4_Q1
MyRData %>%
  select(Total_Amt_Chng_Q4_Q1, Total_Ct_Chng_Q4_Q1) %>%
  ggpairs()
# Out:
# plot without title

# %% [markdown]
# Plot ini menghubungkan variabel antara Total_Amt_Chng_Q4_Q1 dengan Total_Ct_Chng_Q4_Q1. Dilihat dari grafik diatas terdapat hubungan antara Total_Amt_Chng_Q4_Q1 dengan Total_Ct_Chng_Q4_Q1 Semakin banyak transaction amount change pada Q4 Q1, semakin banyak pula transaction count change pada Q4 Q1 nya
